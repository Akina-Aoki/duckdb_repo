# %% [markdown]
# # Workflow documentation of the video code along

# %% [markdown]
# # 1 Setting uo the folders

# %%
adelo@Aira MSYS ~/de25/aira_sql/video_code_along/06_crud_op/sql (main)
$ touch create_statement.sql alter.sql drop.sq
l 1_crud_create.sql 2_crud_read.sql 3_crud_upd
ate.sql 4_crud_delete.sql

# %% [markdown]
# Create code in vscode and copy the query in the ui cells and run to see the results.
#
# See in the ui that its now connected to glossary

# %%
duckdb -ui glossary.duckdb

# %% [markdown]
# In the "create_statement.sql" file
# .... work the query there

# %% [markdown]
# In the crud_create.sql file
# .... work the query there

# %% [markdown]
# In the crud_read.sql
# .... work the query there

# %% [markdown]
# In the alter.sql
# .... work the query there

# %%
-- modify the table
ALTER TABLE database.duckdb -- specify the table
ADD COLUMN learnt BOOLEAN DEFAULT FALSE; -- add a new column with default value

# %% [markdown]
# In the crud_update.sql
# .... work the query there
#
# -- update a column called "learnt" in the dababase
# -- update the glossaries that I have learnt from FALSE in alter.sql to TRUE here in crud_update.sql
