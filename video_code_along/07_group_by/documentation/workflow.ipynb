# %% [markdown]
# # Workflow of Group by video lecture

# %% [markdown]
# Download the csv file of the dataset in Kaggle.
#
# https://www.kaggle.com/datasets/GoogleNewsLab/food-searches-on-google-since-2004

# %% [markdown]
# Create the data and sql folder. Under the sql folder, create the follwoing:

# %%
$ touch eda_food.sql group_by.sql ingest_food.
sql transformations.sql

# %% [markdown]
# ## 1. Work In the ingest_food.sql...
# - Ingest the csv file data into the duckdb database.
# - In the 07_group_by root  ingest the file:
# `duckdb google_search.duckdb < sql/ingest_food.sql`
#
# Then create the ui
# `duckdb -ui google_search.duckdb`

# %% [markdown]
# 2. Work in the eda_food.sql
# 3. Work in the transformations.sql
#
# ## 4. Work in the group_by.sql
# Group by mechanics illustration:
# ![image.png](attachment:image.png)
# Goal: Aggregation using Group by
# - Find a category of food that has to be grouped by. I chose FROZEN YOGURT.
# - All the forzen yogurt, I want to be one frozen yougrt. And then I want to do an aggregation of another column, that is aggregation on number of searches.
# - Choose the aggregation function as a sum. Means, get the sum of all the searches for frozen yogurt and other food categories like pizza.
# - There are several food categories with a lot of rows. And all these rows will be condensed to one row for each category.
# - Then, the number of searches for this food category will be aggregated with a sum.
# - The result will be the figure above.

# %% [markdown]
# ##
